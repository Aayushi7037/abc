# %%
# %pip install pandas

# %%
import pandas as pd
s = pd.Series()
print (s)

# %%
a=input("enter a value for lcm")
for i in range(2,a):
    b=a/2

# %%
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)

# %%
import pandas as pd
a=pd.series[1,2,3,4]
print(a)

# %%
import pandas as pd
a=[1,2,3,4]
app=pd.series(a)
print(a)

# %%
import pandas as pd
a=[1,2,3,4]
app=pd.series(a)
print(a)

# %%
import pandas as pd
a=[1,2,3,4]
app=pd.Series(a)
print(app)

# %%
import pandas as pd
a=[1,2,34,56]
arr=pd.Series(a)
print(arr[1])
# Out:
# 2

# %%
import pandas as pd
a=["aayushi","sharan","kamal"]
arr=pd.Series(a,index=["a","b","c"])
print(arr)
# Out:
# a    aayushi
# b     sharan
# c      kamal
# dtype: object

# %%
import pandas as pd

index = [
    ('Amritsar', 2000), ('Amritsar', 2010),
    ('Hoshiarpur', 2000), ('Hoshiarpur', 2010),
    ('Ludhiana', 2000), ('Ludhiana', 2010)
]

populations = [
    2123656, 2490656,
    1234625, 1586625,
    2898739, 3498739
]

pop = pd.Series(populations, index=index)

pop
# Out:
# (Amritsar, 2000)      2123656
# (Amritsar, 2010)      2490656
# (Hoshiarpur, 2000)    1234625
# (Hoshiarpur, 2010)    1586625
# (Ludhiana, 2000)      2898739
# (Ludhiana, 2010)      3498739
# dtype: int64

# %%
import pandas as pd
key=[
    ('aayushi',10),('aayushi',12),
    ('kamal',12),('kamal',12)
    ]

values=[
87,67,
78,45
]
print(pd.Series(values,index=key))
# Out:
# (aayushi, 10)    87
# (aayushi, 12)    67
# (kamal, 12)      78
# (kamal, 12)      45
# dtype: int64

# %%
import pandas as pd
key=[
    ('aayushi',10),('aayushi',12),
    ('kamal',12),('kamal',15)
    ]

values=[
87,67,
78,45
]
print(pd.Series(values,index=key))
print("--------------------")
print(pd.MultiIndex.from_tuples(key))
print("---------------------")
pop = pop.reindex(key)

pop
# Out:
# (aayushi, 10)    87
# (aayushi, 12)    67
# (kamal, 12)      78
# (kamal, 12)      45
# dtype: int64
# --------------------
# MultiIndex([('aayushi', 10),
#             ('aayushi', 12),
#             (  'kamal', 12),
#             (  'kamal', 12)],
#            )
# ---------------------
# (aayushi, 10)   NaN
# (aayushi, 12)   NaN
# (kamal, 12)     NaN
# (kamal, 12)     NaN
# dtype: float64

# %%
import pandas as pd
key=[
    ('aayushi',10),('aayushi',12),
    ('kamal',12),('kamal',12)
    ]

values=[
87,67,
78,45
]
print(pd.Series(values,index=key))
print("--------------------")
# p1=pop[('aayushi',12):('kamal',12)]
# print(p1)
pop[('Aayushi', 12):('kamal', 15)]

[i for i in pop.index if i[1] == 2012]

pop_df = pop.unstack()
pop_df
# Out:
# (aayushi, 10)    87
# (aayushi, 12)    67
# (kamal, 12)      78
# (kamal, 12)      45
# dtype: int64
# --------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File pandas/_libs/index.pyx:219, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# TypeError: '<' not supported between instances of 'tuple' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(
    np.random.rand(4, 2), """--------------------------------------------------------"""
    index=[['a', 'a', 'b', 'b'], [1, 2, 1, 2]],
    columns=['data1', 'data2']
)

df
# Out:
#         data1     data2
# a 1  0.488344  0.757064
#   2  0.008833  0.684383
# b 1  0.164273  0.617759
#   2  0.219829  0.351119

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,3])
y=np.array([2,4,6])
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# %pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 8.1/8.1 MB 9.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.6/1.6 MB 7.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 73.4/73.4 KB 3.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 122.8/122.8 KB 7.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.0/7.0 MB 9.2 MB/s eta 0:00:00
# ...
#      ------------------------------------- 221.2/221.2 KB 14.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the 'c:\Users\hp\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
x=np.array([1,2,34,5,6,7,8])
y=np.array([6,3,5,4,2,2,9])
plt.plot(x,y,"o")
plt.show()

# %%
import pandas as pd
data = {
    ('Amritsar', 2000): 2123656,
    ('Amritsar', 2010): 2490656,
    ('Hoshiarpur', 2000): 1234625,
    ('Hoshiarpur', 2010): 1586625,
    ('Ludhiana', 2000): 2898739,
    ('Ludhiana', 2010): 3498739
}

w = pd.Series(data)
w
# Out:
# Amritsar    2000    2123656
#             2010    2490656
# Hoshiarpur  2000    1234625
#             2010    1586625
# Ludhiana    2000    2898739
#             2010    3498739
# dtype: int64

# %%
w.unstack()
# Out:
#                2000     2010
# Amritsar    2123656  2490656
# Hoshiarpur  1234625  1586625
# Ludhiana    2898739  3498739

# %%
arrays = [['Aayushi', 'Aayushi', 'Babita', 'Babita'], ['data science','cyber','data science','cyber']]
index = pd.MultiIndex.from_arrays(arrays)

df = pd.DataFrame({'Marks':[80, 85, 78, 90]}, index=index)
print(df)
# Out:
#                       Marks
# Aayushi data science     80
#         cyber            85
# Babita  data science     78
#         cyber            90

# %%
df1 =  pd.Series(
    {
        ("a", 1): [1, 2, 3],
        ("a", 2): [4, 5, 6],
        ("b", 1): [7, 8, 9],
    },

)
df1
# Out:
# a  1    [1, 2, 3]
#    2    [4, 5, 6]
# b  1    [7, 8, 9]
# dtype: object

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame(
    np.random.rand(4, 2), #----------------------------------------
    index=[['a', 'a', 'b', 'b'], [1, 2, 1, 2]],
    columns=['data1', 'data2']
)
df
# Out:
#         data1     data2
# a 1  0.965050  0.052128
#   2  0.723173  0.847785
# b 1  0.292273  0.350360
#   2  0.494649  0.676779
